# %% [markdown]
# # Introduction: Sorting out cities and city districts
#
# Because on the website, for real estate listings, user validation was not set in place for verifying city and city district information, in some of the real estete entries there is wrong information about the location.
#
# After initial data cleaning, in this jupyter notebook, we will try to sort out and set the correct information for the location of a real estete entry.

# %% [markdown]
# # 1. Connecting to the database

# %%
# Importting libraries
import json
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Loading db connection parameters from json file
db_params = None
with open('../database/db_connetion.json') as db_file:
    # Loading db connection parameters 
    db_params = json.load(db_file)

# %%
# Connecting to the database
conn = psycopg2.connect(
    host=db_params['host'], 
    port=db_params['port'], 
    database=db_params['database'], 
    user=db_params['user'], 
    password=db_params['password']
    )

# %%
# Getting the real estate data from database
real_estate = pd.read_sql_query('Select * from properties_clean', conn)

# %% [markdown]
# # 2. Removing serbian specific latin characters
#
# For convenience and data consistency, first we will remove any specific serbian latin characters.

# %%
def _replace_latin_characters(value):
    if value is None:
        return None
    value = value.lower()
    value = value.replace('ć', 'c')
    value = value.replace('č', 'c')
    value = value.replace('š', 's')
    value = value.replace('đ', 'dj')
    value = value.replace('ž', 'z')
    return value

# %%
print(f'Changing latin characters for f{len(real_estate)} real estate entries')
for index in range(0, len(real_estate)):
    current_real_estate = real_estate.iloc[index, :]
    real_estate.at[index, 'location_city'] = _replace_latin_characters(current_real_estate['location_city'])
    real_estate.at[index, 'location_city_district'] = _replace_latin_characters(current_real_estate['location_city_district'])
# Out:
# Changing latin characters for f21604 real estate entries

# %% [markdown]
# # 3. Finding wrong entries for city and city distric location
#
# Using geographical knowlegde of Serbia and it's couple of biggest cities, we should be able to detect where there are a wrong information about real estate locations.

# %%
# Listing top cities by number of listed properties withing them
real_estate.groupby(['location_city']).count().sort_values('id', ascending=False).head(50)
# Out:
#                               id  listing_type  property_type  price  \
# location_city
# beograd                    11487         11487          11487  11487
# novi sad                    4221          4221           4221   4221
# gradske lokacije             899           899            899    899
# kragujevac                   687           687            687    687
# nis                          523           523            523    523
# srbija                       523           523            523    523
# stari grad                   228           228            228    228
# subotica                     125           125            125    125
# palilula                     119           119            119    119
# vozdovac                     105           105            105    105
# zvezdara                      96            96             96     96
# subotica opstina              91            91             91     91
# zemun                         90            90             90     90
# novi beograd                  87            87             87     87
# medijana                      77            77             77     77
# savski venac                  76            76             76     76
# novi beo                      75            75             75     75
# stara pazova opstina          75            75             75     75
# zrenjanin opstina             57            57             57     57
# vracar                        54            54             54     54
# cukarica                      53            53             53     53
# grocka                        49            49             49     49
# indjija opstina               48            48             48     48
# vrnjacka banja opstina        41            41             41     41
# rakovica                      36            36             36     36
# novi sad - centar             35            35             35     35
# telep                         34            34             34     34
# zrenjanin                     33            33             33     33
# sombor opstina                31            31             31     31
# irig opstina                  25            25             25     25
# zlatibor opstina              25            25             25     25
# sopot                         24            24             24     24
# obrenovac                     24            24             24     24
# sombor                        23            23             23     23
# kraljevo opstina              23            23             23     23
# pantelej                      22            22             22     22
# surcin                        21            21             21     21
# barajevo                      20            20             20     20
# sremska mitrovica opstina     20            20             20     20
# valjevo opstina               19            19             19     19
# grbavica                      19            19             19     19
# ruma opstina                  19            19             19     19
# okolne lokacije               18            18             18     18
# beocin opstina                18            18             18     18
# cacak opstina                 17            17             17     17
# sremska kamenica              17            17             17     17
# sabac opstina                 16            16             16     16
# loznica                       16            16             16     16
# pancevo opstina               16            16             16     16
# smederevo opstina             15            15             15     15
#
#                            location_city_district  area_property  area_land  \
# location_city
# beograd                                     11462          11487       1454
# novi sad                                     4177           4221        320
# gradske lokacije                              899            899        129
# kragujevac                                    480            687        351
# nis                                           453            523         58
# srbija                                        523            523        321
# stari grad                                    228            228         11
# subotica                                      125            125         96
# palilula                                      119            119         61
# vozdovac                                      105            105         58
# zvezdara                                       96             96         39
# subotica opstina                               91             91         66
# zemun                                          90             90         46
# novi beograd                                   87             87          6
# medijana                                       77             77         16
# savski venac                                   76             76         37
# novi beo                                       75             75         15
# stara pazova opstina                           75             75         45
# zrenjanin opstina                              56             57         49
# vracar                                         54             54         16
# cukarica                                       53             53         38
# grocka                                         49             49         41
# indjija opstina                                48             48         38
# vrnjacka banja opstina                         41             41         31
# rakovica                                       36             36         11
# novi sad - centar                              35             35          8
# telep                                          34             34         16
# zrenjanin                                      33             33         26
# sombor opstina                                 31             31         28
# irig opstina                                   23             25         14
# zlatibor opstina                               21             25          9
# sopot                                          24             24         16
# obrenovac                                      24             24         20
# sombor                                         23             23         16
# kraljevo opstina                               22             23         20
# pantelej                                       22             22         14
# surcin                                         21             21         16
# barajevo                                       20             20         16
# sremska mitrovica opstina                      20             20         16
# valjevo opstina                                19             19         15
# grbavica                                       19             19          2
# ruma opstina                                   19             19         17
# okolne lokacije                                18             18         15
# beocin opstina                                 18             18          9
# cacak opstina                                  16             17         11
# sremska kamenica                               17             17         13
# sabac opstina                                  16             16         10
# loznica                                        16             16         11
# pancevo opstina                                15             16          8
# smederevo opstina                              14             15         13
#
#                            construction_type  num_floors_building  \
# location_city
# beograd                                 2359                 4857
# novi sad                                1714                 2406
# gradske lokacije                         142                  244
# kragujevac                               103                  177
# nis                                       65                  100
# srbija                                   182                   61
# stari grad                                42                  135
# subotica                                  32                    8
# palilula                                  52                   32
# vozdovac                                  19                   21
# zvezdara                                  25                   29
# subotica opstina                          17                    2
# zemun                                     27                   15
# novi beograd                               8                   55
# medijana                                  20                   23
# savski venac                              26                   15
# novi beo                                  18                   30
# stara pazova opstina                      32                    8
# zrenjanin opstina                         12                    1
# vracar                                    14                   19
# cukarica                                  15                    6
# grocka                                    14                    1
# indjija opstina                           14                    0
# vrnjacka banja opstina                     7                    3
# rakovica                                  16                   13
# novi sad - centar                          7                   11
# telep                                     10                   10
# zrenjanin                                  7                    2
# sombor opstina                             5                    0
# irig opstina                               8                    0
# zlatibor opstina                          13                    8
# sopot                                      1                    0
# obrenovac                                  5                    0
# sombor                                     6                    0
# kraljevo opstina                          10                    0
# pantelej                                   8                    3
# surcin                                     6                    0
# barajevo                                   6                    0
# sremska mitrovica opstina                  7                    0
# valjevo opstina                            5                    1
# grbavica                                   4                   11
# ruma opstina                              11                    0
# okolne lokacije                            5                    0
# beocin opstina                             4                    0
# cacak opstina                              9                    1
# sremska kamenica                           1                    0
# sabac opstina                              3                    0
# loznica                                    5                    4
# pancevo opstina                            6                    0
# smederevo opstina                          3                    1
#
#                            apartment_floor  registered  heating_type  \
# location_city
# beograd                               8013       11487         10465
# novi sad                              3314        4221          3265
# gradske lokacije                       554         899           620
# kragujevac                             253         687           470
# nis                                    199         523           282
# srbija                                  83         523           391
# stari grad                             202         228           204
# subotica                                14         125            88
# palilula                                38         119            90
# vozdovac                                29         105            72
# zvezdara                                39          96            75
# subotica opstina                         5          91            71
# zemun                                   25          90            63
# novi beograd                            68          87            81
# medijana                                46          77            52
# savski venac                            18          76            57
# novi beo                                48          75            56
# stara pazova opstina                     8          75            56
# zrenjanin opstina                        2          57            37
# vracar                                  32          54            39
# cukarica                                 8          53            37
# grocka                                   1          49            30
# indjija opstina                          1          48            32
# vrnjacka banja opstina                   3          41            11
# rakovica                                18          36            30
# novi sad - centar                       17          35            23
# telep                                   12          34            24
# zrenjanin                                2          33            23
# sombor opstina                           0          31            11
# irig opstina                             1          25            13
# zlatibor opstina                        10          25            16
# sopot                                    0          24            14
# obrenovac                                1          24            10
# sombor                                   0          23            18
# kraljevo opstina                         0          23            13
# pantelej                                 3          22            14
# surcin                                   0          21            16
# barajevo                                 0          20            11
# sremska mitrovica opstina                0          20            10
# valjevo opstina                          1          19            15
# grbavica                                12          19            13
# ruma opstina                             1          19            14
# okolne lokacije                          0          18            11
# beocin opstina                           0          18            11
# cacak opstina                            1          17            13
# sremska kamenica                         0          17             7
# sabac opstina                            0          16             7
# loznica                                  4          16            13
# pancevo opstina                          3          16            14
# smederevo opstina                        1          15            11
#
#                            num_rooms  num_bathrooms  source
# location_city
# beograd                         8999          11487   11487
# novi sad                        3474           4221    4221
# gradske lokacije                 592            899     899
# kragujevac                       263            687     687
# nis                              224            523     523
# srbija                            89            523     523
# stari grad                       207            228     228
# subotica                          15            125     125
# palilula                          42            119     119
# vozdovac                          32            105     105
# zvezdara                          44             96      96
# subotica opstina                   7             91      91
# zemun                             28             90      90
# novi beograd                      68             87      87
# medijana                          56             77      77
# savski venac                      21             76      76
# novi beo                          54             75      75
# stara pazova opstina               8             75      75
# zrenjanin opstina                  2             57      57
# vracar                            35             54      54
# cukarica                           9             53      53
# grocka                             1             49      49
# indjija opstina                    0             48      48
# vrnjacka banja opstina             3             41      41
# rakovica                          18             36      36
# novi sad - centar                 24             35      35
# telep                             12             34      34
# zrenjanin                          2             33      33
# sombor opstina                     1             31      31
# irig opstina                       1             25      25
# zlatibor opstina                  10             25      25
# sopot                              0             24      24
# obrenovac                          1             24      24
# sombor                             0             23      23
# kraljevo opstina                   0             23      23
# pantelej                           3             22      22
# surcin                             0             21      21
# barajevo                           0             20      20
# sremska mitrovica opstina          0             20      20
# valjevo opstina                    1             19      19
# grbavica                          14             19      19
# ruma opstina                       1             19      19
# okolne lokacije                    0             18      18
# beocin opstina                     0             18      18
# cacak opstina                      1             17      17
# sremska kamenica                   0             17      17
# sabac opstina                      0             16      16
# loznica                            4             16      16
# pancevo opstina                    3             16      16
# smederevo opstina                  1             15      15

# %% [markdown]
# ### Now we know that for some entries, city district information is misplaced with city information. In city filed, we can actually find infomation of city district:
# - gradske lokacije
# - medijana
# - srbija
# - stari grad
# - palilula
# - vozdovac
# - zvezdara
# - zemun
# - novi beograd
# - ...
#
# We will try to set the right city and city district information on them.

# %% [markdown]
# # 4. Setting the right location information

# %% [markdown]
# ## 4.1. Properties with "gradske lokacije" city value

# %%
# All entries with "Gradske lokacije" city info
indexes_to_replace = real_estate[real_estate['location_city'] == 'gradske lokacije'].index
real_estate.iloc[indexes_to_replace, :]
# Out:
#           id listing_type property_type    price     location_city  \
# 44       113            s             a  62000.0  gradske lokacije
# 45       114            s             a  82000.0  gradske lokacije
# 46       115            s             a  85000.0  gradske lokacije
# 133      271            s             a  48000.0  gradske lokacije
# 137      275            s             a  41000.0  gradske lokacije
# ...      ...          ...           ...      ...               ...
# 20728  21523            r             a    300.0  gradske lokacije
# 20923  21718            r             a    300.0  gradske lokacije
# 20973  21768            r             a    270.0  gradske lokacije
# 20985  21780            r             a    220.0  gradske lokacije
# 21548  22343            r             a    150.0  gradske lokacije
#
#       location_city_district  area_property  area_land construction_type  \
# 44                  medijana           72.0        NaN              None
# 45                  medijana           80.0        NaN              None
# 46                  medijana           96.0        NaN              None
# 133                 medijana           47.0        NaN              None
# 137                 medijana           42.0        NaN              2020
# ...                      ...            ...        ...               ...
# 20728               medijana           50.0        NaN              None
# 20923               medijana           50.0        NaN              None
# 20973               medijana           55.0        NaN              None
# 20985               pantelej           44.0        NaN              None
# 21548             stari grad           36.0        NaN              None
#
#        num_floors_building  apartment_floor  registered heating_type  \
# 44                     NaN              3.0        True    Centralno
# 45                     NaN              0.0        True       Struja
# 46                     NaN              7.0        True    Centralno
# 133                    7.0              7.0        True    Centralno
# 137                    3.0              3.0        True       Struja
# ...                    ...              ...         ...          ...
# 20728                  NaN              1.0       False    Centralno
# 20923                  NaN              1.0       False       Etažno
# 20973                  NaN              0.0        True    Centralno
# 20985                  NaN              1.0       False         None
# 21548                  NaN              1.0        True    Centralno
#
#        num_rooms  num_bathrooms  \
# 44           3.0            1.0
# 45           4.0            2.0
# 46           3.5            1.0
# 133          1.0            1.0
# 137          1.5            1.0
# ...          ...            ...
# 20728        2.0            1.0
# 20923        1.5            1.0
# 20973        2.5            1.0
# 20985        1.5            1.0
# 21548        1.0            1.0
#
#                                                   source
# 44     https://www.4zida.rs/prodaja/stanovi/nis/oglas...
# 45     https://www.4zida.rs/prodaja/stanovi/nis/oglas...
# 46     https://www.4zida.rs/prodaja/stanovi/nis/oglas...
# 133    https://www.4zida.rs/prodaja/stanovi/nis/oglas...
# 137    https://www.4zida.rs/prodaja/stanovi/nis/oglas...
# ...                                                  ...
# 20728  https://www.4zida.rs/izdavanje/stanovi/nis/ogl...
# 20923  https://www.4zida.rs/izdavanje/stanovi/nis/ogl...
# 20973  https://www.4zida.rs/izdavanje/stanovi/nis/ogl...
# 20985  https://www.4zida.rs/izdavanje/stanovi/nis/ogl...
# 21548  https://www.4zida.rs/izdavanje/stanovi/kraguje...
#
# [899 rows x 16 columns]

# %%
# Trying to get the right city information from source link
for index in indexes_to_replace:
    print(real_estate.iloc[index,-1])
    break
# Out:
# https://www.4zida.rs/prodaja/stanovi/nis/oglas/cair/5f0452680c7cde014c6fa13b

# %% [markdown]
# #### We can see that city data is embeded into the source link. We will extract city info from that link and store it as the correct city info.

# %%
def set_city_info_from_source(index):
    """Extracts city infromation from source link and set's up the correct city information."""
    try:
        current_real_estate = real_estate.iloc[index, :] 
        if 'stanovi' in current_real_estate['source']:
            city = current_real_estate['source'].split('stanovi/')[1].split('/')[0]
        elif 'kuce' in current_real_estate['source']:
            city = current_real_estate['source'].split('kuce/')[1].split('/')[0]
        city = city.replace('-', ' ')
        real_estate.at[index, 'location_city'] = city
    except Exception as e:
        pass

# %%
print(f'Updating city information on {len(indexes_to_replace)} properties.')
for index in indexes_to_replace:
    set_city_info_from_source(index)
# Out:
# Updating city information on 899 properties.

# %% [markdown]
# ## 4.2. Properties with "srbija" city value
#
# Properties where serbia was set as the city information. Actual city informatio is here under city district column, so we will just copy city district column value to city value and set city district to be an None value.

# %%
# All entries with "Gradske lokacije" city info
indexes_to_replace = real_estate[real_estate['location_city'] == 'srbija'].index
real_estate.iloc[indexes_to_replace, :]
# Out:
#           id listing_type property_type     price location_city  \
# 343      478            s             a   36000.0        srbija
# 377      512            s             a   47400.0        srbija
# 382      517            s             a   31000.0        srbija
# 550      684            s             a  115000.0        srbija
# 633      766            s             a   70000.0        srbija
# ...      ...          ...           ...       ...           ...
# 16509  17181            r             a     350.0        srbija
# 16909  17597            r             a      90.0        srbija
# 16953  17642            r             a     300.0        srbija
# 17739  18477            r             a     200.0        srbija
# 18345  19104            r             a     100.0        srbija
#
#       location_city_district  area_property  area_land construction_type  \
# 343           sombor opstina           47.0        NaN              2018
# 377               kragujevac           64.0        NaN              None
# 382               kragujevac           57.0        NaN              None
# 550         kopaonik opstina           30.0        NaN              None
# 633         zlatibor opstina           66.0        NaN              2004
# ...                      ...            ...        ...               ...
# 16509                    nis           98.0        NaN              2007
# 16909       jagodina opstina           24.0        NaN              None
# 16953                beograd           38.0        NaN              None
# 17739               novi sad           25.0        NaN              1936
# 18345             kragujevac           30.0        NaN              None
#
#        num_floors_building  apartment_floor  registered heating_type  \
# 343                    4.0              3.0        True        Podno
# 377                    5.0              3.0        True    Centralno
# 382                    5.0              5.0        True    Centralno
# 550                    4.0              1.0        True    Centralno
# 633                    NaN              0.0        True       Etažno
# ...                    ...              ...         ...          ...
# 16509                  5.0              1.0        True    Centralno
# 16909                  NaN              1.0       False    Centralno
# 16953                  6.0              2.0       False       Struja
# 17739                  NaN              NaN       False    Centralno
# 18345                  NaN              4.0       False    Centralno
#
#        num_rooms  num_bathrooms  \
# 343          1.5            1.0
# 377          2.5            1.0
# 382          2.0            1.0
# 550          1.0            1.0
# 633          3.0            2.0
# ...          ...            ...
# 16509        3.5            1.0
# 16909        1.0            1.0
# 16953        1.5            1.0
# 17739        1.0            1.0
# 18345        1.0            1.0
#
#                                                   source
# 343    https://www.4zida.rs/prodaja/stanovi/sombor-op...
# 377    https://www.4zida.rs/prodaja/stanovi/kragujeva...
# 382    https://www.4zida.rs/prodaja/stanovi/kragujeva...
# 550    https://www.4zida.rs/prodaja/stanovi/kopaonik-...
# 633    https://www.4zida.rs/prodaja/stanovi/zlatibor-...
# ...                                                  ...
# 16509  https://www.4zida.rs/izdavanje/stanovi/nis/ogl...
# 16909  https://www.4zida.rs/izdavanje/stanovi/jagodin...
# 16953  https://www.4zida.rs/izdavanje/stanovi/beograd...
# 17739  https://www.4zida.rs/izdavanje/stanovi/novi-sa...
# 18345  https://www.4zida.rs/izdavanje/stanovi/kraguje...
#
# [523 rows x 16 columns]

# %%
print(f'Updating city information on {len(indexes_to_replace)} properties.')
for index in indexes_to_replace:
    try:
        real_estate.at[index, 'location_city'] = real_estate.iloc[index, :]['location_city_district']
        real_estate.at[index, 'location_city_district'] = None
    except Exception as e:
        pass
# Out:
# Updating city information on 523 properties.

# %% [markdown]
# ## 4.3. Setting the correct Belgrade's districts
#
# For Belgrade, city information is incorrectly placed. In city column there are actually values for city districts:
# - stari grad
# - palilula
# - vozdovac
# - zvezdara
# - zemun
# - novi beograd
# - savski venac
# - novi beo
# - vracar
# - cukarica
# - grocka
# - rakovica
# - obrenovac
# - surcin
# - barajevo

# %%
belgrade_districts = [
    'stari grad',
    'palilula',
    'vozdovac',
    'zvezdara',
    'zemun',
    'novi beograd',
    'savski venac',
    'novi beo',
    'vracar',
    'cukarica',
    'grocka',
    'rakovica',
    'obrenovac',
    'surcin',
    'barajevo',
    'mladenovac'
]

# %%
# All entries with wrong Belgrade city info
for belgrade_district in belgrade_districts:
    indexes_to_replace = real_estate[real_estate['location_city'] == belgrade_district].index
    for index in indexes_to_replace:
        real_estate.at[index, 'location_city_district'] = real_estate.iloc[index, :]['location_city']
        real_estate.at[index, 'location_city'] = 'beograd'

# %% [markdown]
# ## 4.4. Adjusting all properties where in city name says "optsina"

# %%
# All entries with "Gradske lokacije" city info
indexes_to_replace = real_estate[real_estate['location_city'].str.contains('opstina')].index
real_estate.iloc[indexes_to_replace, :].head()
# Out:
#       id listing_type property_type    price     location_city  \
# 55   193            s             a  48500.0  subotica opstina
# 246  383            s             a  49900.0  subotica opstina
# 343  478            s             a  36000.0    sombor opstina
# 347  482            s             a  15000.0  subotica opstina
# 392  527            s             a  37000.0     uzice opstina
#
#     location_city_district  area_property  area_land construction_type  \
# 55                   palic           69.0        NaN              None
# 246             kragujevac           70.0        NaN              None
# 343                   None           47.0        NaN              2018
# 347                  palic           51.0        NaN              None
# 392             kragujevac           57.0        NaN              None
#
#      num_floors_building  apartment_floor  registered heating_type  num_rooms  \
# 55                   NaN              1.0        True         None        2.5
# 246                 10.0              9.0        True    Centralno        2.5
# 343                  4.0              3.0        True        Podno        1.5
# 347                  NaN              0.0        True       Struja        1.5
# 392                 10.0              9.0        True    Centralno        2.0
#
#      num_bathrooms                                             source
# 55             1.0  https://www.4zida.rs/prodaja/stanovi/subotica-...
# 246            1.0  https://www.4zida.rs/prodaja/stanovi/subotica-...
# 343            1.0  https://www.4zida.rs/prodaja/stanovi/sombor-op...
# 347            1.0  https://www.4zida.rs/prodaja/stanovi/subotica-...
# 392            1.0  https://www.4zida.rs/prodaja/stanovi/uzice-ops...

# %%
# Trying to get the right city information from source link
for index in indexes_to_replace:
    print(real_estate.iloc[index,-1])
    break
# Out:
# https://www.4zida.rs/prodaja/stanovi/subotica-opstina/oglas/palic/5f3e56ad4a8b220a123863e3

# %%
print(f'Updating location information on {len(indexes_to_replace)} ')
for index in indexes_to_replace:
    real_estate.at[index, 'location_city_district'] = real_estate.iloc[index,:]['location_city']
    real_estate.at[index, 'location_city'] = real_estate.iloc[index,:]['location_city'].replace('opstina', '').strip()
# Out:
# Updating location information on 1378

# %% [markdown]
# ## 4.5. Setting the correct Novi Sad's districts
#
# For Novi Sad, city information is incorrectly placed. In city column there are actually values for city districts:
# - telep
# - novi sad - centar
# - veternik
# - bulevar oslobodjenja

# %%
novi_sad_districts = [
    'telep',
    'novi sad - centar',
    'veternik',
    'bulevar oslobodjenja',
    'petrovaradin'
]

# %%
# All entries with wrong Novi Sad's city info
for novi_sad_district in novi_sad_districts:
    indexes_to_replace = real_estate[real_estate['location_city'] == novi_sad_district].index
    for index in indexes_to_replace:
        real_estate.at[index, 'location_city_district'] = real_estate.iloc[index, :]['location_city']
        real_estate.at[index, 'location_city'] = 'novi sad'

# %% [markdown]
# ## 4.6. Setting the correct city name for "medijana" city district (Nis)

# %%
# All entries with "Gradske lokacije" city info
indexes_to_replace = real_estate[real_estate['location_city'] == 'medijana'].index
real_estate.iloc[indexes_to_replace, :].head()
# Out:
#       id listing_type property_type    price location_city  \
# 126  264            s             a  77000.0      medijana
# 132  270            s             a  54400.0      medijana
# 136  274            s             a  56500.0      medijana
# 230  367            s             a  62500.0      medijana
# 238  375            s             a  35000.0      medijana
#
#           location_city_district  area_property  area_land construction_type  \
# 126            bulevar nemanjica           75.0        NaN              None
# 132             gradske lokacije           64.0        NaN              None
# 136            bulevar nemanjica           62.0        NaN              None
# 230            bulevar nemanjica           84.0        NaN              None
# 238  bulevar dr zorana djindjica           42.0        NaN              2003
#
#      num_floors_building  apartment_floor  registered heating_type  num_rooms  \
# 126                  NaN              2.0        True       Struja        3.0
# 132                  3.0              2.0        True          Gas        3.0
# 136                  7.0              6.0        True    Centralno        2.0
# 230                  NaN              8.0       False    Centralno        3.5
# 238                  6.0              5.0        True       TA peć        1.5
#
#      num_bathrooms                                             source
# 126            1.0  https://www.4zida.rs/prodaja/stanovi/nis/oglas...
# 132            1.0  https://www.4zida.rs/prodaja/stanovi/subotica-...
# 136            1.0  https://www.4zida.rs/prodaja/stanovi/nis/oglas...
# 230            1.0  https://www.4zida.rs/prodaja/stanovi/nis/oglas...
# 238            1.0  https://www.4zida.rs/prodaja/stanovi/nis/oglas...

# %%
print(f'Updating city information on {len(indexes_to_replace)} properties.')
for index in indexes_to_replace:
    try:
        real_estate.at[index, 'location_city_district'] = real_estate.iloc[index, :]['location_city']
        real_estate.at[index, 'location_city'] = 'nis'
    except Exception as e:
        pass
# Out:
# Updating city information on 77 properties.

# %% [markdown]
# ## 4.7. Removing entries that contain "okolne lokacije" value for city district

# %%
indexes_to_remove = real_estate[real_estate['location_city'] == 'okolne lokacije'].index

# %%
print(f'There are {len(indexes_to_remove)} real estate entries entries to be removed.')
# Out:
# There are 18 real estate entries entries to be removed.

# %%
real_estate = real_estate.drop(indexes_to_remove)

# %% [markdown]
# # 5. Saving cleaned dataset

# %%
len(real_estate)
# Out:
# 21586

# %% [markdown]
# ## 5.1. Exporting to .csv file

# %%
# Saving results to the csv file
real_estate.to_csv('../database/backup/properties_cleaned_data.csv',index=False)

# %% [markdown]
# ## 5.2. Inserting into database
#
# Saving cleaned results into new table, table that containes final, cleaned data, ready for analysis.

# %%
# Creating new PostgreSQL engine 
from sqlalchemy import create_engine

postgres_engine_parameters = "postgresql://{}:{}@{}:{}/{}".format(
    db_params['user'],
    db_params['password'],
    db_params['host'],
    db_params['port'],
    db_params['database'],
)

postgres_engine = create_engine(postgres_engine_parameters)

# %%
# Inserting cleaned data into "real_estate" table via sqlalchemy engine 
real_estate.to_sql('real_estate', postgres_engine, index=False)

# %% [markdown]
# # 6. Closing database connection

# %%
# Closing connection
if conn:
    conn.close()
